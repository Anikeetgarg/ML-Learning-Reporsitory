# %%
import torch
import numpy
import matplotlib.pyplot as plt
import pandas
from torch import nn

# %%
 torch.__version__
# Out:
# '2.3.1+cu121'

# %%
## known variables

weight = 0.7
bias = 0.3

## creating a linear model
start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(1)
y = weight * X + bias

# %%
X.shape, y.shape
# Out:
# (torch.Size([50, 1]), torch.Size([50, 1]))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size= 0.8)

# %%
def plot_prediction(train_data = X_train, train_label = y_train, test_data = X_test, test_label = y_test, prediction = None):
    plt.figure(figsize=(10, 7))
    
    plt.scatter(train_data, train_label, c="b", label = "Train data")
    plt.scatter(test_data, test_label, c="g", label = "Test data")

    if prediction != None:
        plt.scatter(test_data, prediction, c="purple", label = "Test data")
        
    
    plt.xlabel("X")
    plt.ylabel("y")
    plt.grid()
    plt.title("Traning data")
    plt.legend()

plot_prediction(X_train, y_train, X_test, y_test)

# %%
# linear regression model
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(1, dtype= torch.float, requires_grad = True))
        self.bias = nn.Parameter(torch.randn(1, dtype = torch.float, requires_grad = True))

    def forward(self, x: torch.tensor) -> torch.tensor:
        return self.weights * x + self.bias

# %%
model_0 = LinearRegressionModel()

# %%
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([1.6171], requires_grad=True),
#  Parameter containing:
#  tensor([-2.8753], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([1.6171])), ('bias', tensor([-2.8753]))])

# %%
with torch.inference_mode():
    y_preds = model_0.forward(X_test)

    
y_preds

plot_prediction(prediction= y_preds)
#

# %%
# loss function
loss_fn = nn.L1Loss()

# optimiser
optimizer = torch.optim.SGD(params=model_0.parameters(),lr= 0.01)

# %%
 ephocs = 500

for ephoc in range(ephocs):
    model_0.train() # pytorch will start tracking parameters and optimize for gradient decent

    # forward pass
    y_preds =  model_0.forward(X_train)

    # calculate the loss
    loss = loss_fn(y_preds, y_train)

    # reset the optimizer to zero
    optimizer.zero_grad()

    # loss backward 
    loss.backward()

    # steps the optimizer (perform the gradient decent)
    optimizer.step()

    # update the parameters
    model_0.eval()
    
    with torch.inference_mode():
        y_preds_ = model_0(X_test)
        
        loss_test = loss_fn(y_test, y_preds_)
    if ephoc % 10 == 0:
        print(f"Epochs = {ephoc} | Loss = {loss_test} | Params = {model_0.state_dict()}")
# Out:
# Epochs = 0 | Loss = 2.7706267833709717 | Params = OrderedDict([('weights', tensor([1.6222])), ('bias', tensor([-2.8653]))])
# Epochs = 10 | Loss = 2.648991584777832 | Params = OrderedDict([('weights', tensor([1.6727])), ('bias', tensor([-2.7653]))])
# Epochs = 20 | Loss = 2.5273566246032715 | Params = OrderedDict([('weights', tensor([1.7233])), ('bias', tensor([-2.6653]))])
# Epochs = 30 | Loss = 2.405721664428711 | Params = OrderedDict([('weights', tensor([1.7738])), ('bias', tensor([-2.5653]))])
# Epochs = 40 | Loss = 2.2840867042541504 | Params = OrderedDict([('weights', tensor([1.8244])), ('bias', tensor([-2.4653]))])
# Epochs = 50 | Loss = 2.1624512672424316 | Params = OrderedDict([('weights', tensor([1.8749])), ('bias', tensor([-2.3653]))])
# Epochs = 60 | Loss = 2.040816307067871 | Params = OrderedDict([('weights', tensor([1.9255])), ('bias', tensor([-2.2653]))])
# Epochs = 70 | Loss = 1.9191811084747314 | Params = OrderedDict([('weights', tensor([1.9760])), ('bias', tensor([-2.1653]))])
# Epochs = 80 | Loss = 1.7975460290908813 | Params = OrderedDict([('weights', tensor([2.0266])), ('bias', tensor([-2.0653]))])
# Epochs = 90 | Loss = 1.6759109497070312 | Params = OrderedDict([('weights', tensor([2.0771])), ('bias', tensor([-1.9653]))])
# Epochs = 100 | Loss = 1.5542758703231812 | Params = OrderedDict([('weights', tensor([2.1277])), ('bias', tensor([-1.8653]))])
# Epochs = 110 | Loss = 1.432640790939331 | Params = OrderedDict([('weights', tensor([2.1782])), ('bias', tensor([-1.7653]))])
# Epochs = 120 | Loss = 1.3110055923461914 | Params = OrderedDict([('weights', tensor([2.2288])), ('bias', tensor([-1.6653]))])
# Epochs = 130 | Loss = 1.1893705129623413 | Params = OrderedDict([('weights', tensor([2.2793])), ('bias', tensor([-1.5653]))])
# Epochs = 140 | Loss = 1.0677354335784912 | Params = OrderedDict([('weights', tensor([2.3299])), ('bias', tensor([-1.4653]))])
# Epochs = 150 | Loss = 0.9461003541946411 | Params = OrderedDict([('weights', tensor([2.3804])), ('bias', tensor([-1.3653]))])
# Epochs = 160 | Loss = 0.8364790678024292 | Params = OrderedDict([('weights', tensor([2.4228])), ('bias', tensor([-1.2738]))])
# Epochs = 170 | Loss = 0.762529730796814 | Params = OrderedDict([('weights', tensor([2.4521])), ('bias', tensor([-1.1963]))])
# Epochs = 180 | Loss = 0.7053954601287842 | Params = OrderedDict([('weights', tensor([2.4712])), ('bias', tensor([-1.1308]))])
# Epochs = 190 | Loss = 0.6663468480110168 | Params = OrderedDict([('weights', tensor([2.4846])), ('bias', tensor([-1.0723]))])
# Epochs = 200 | Loss = 0.6350764036178589 | Params = OrderedDict([('weights', tensor([2.4922])), ('bias', tensor([-1.0213]))])
# Epochs = 210 | Loss = 0.6087943315505981 | Params = OrderedDict([('weights', tensor([2.4943])), ('bias', tensor([-0.9778]))])
# Epochs = 220 | Loss = 0.5861571431159973 | Params = OrderedDict([('weights', tensor([2.4924])), ('bias', tensor([-0.9398]))])
# Epochs = 230 | Loss = 0.5664945840835571 | Params = OrderedDict([('weights', tensor([2.4875])), ('bias', tensor([-0.9063]))])
# Epochs = 240 | Loss = 0.5491412281990051 | Params = OrderedDict([('weights', tensor([2.4801])), ('bias', tensor([-0.8763]))])
# Epochs = 250 | Loss = 0.534749448299408 | Params = OrderedDict([('weights', tensor([2.4698])), ('bias', tensor([-0.8508]))])
# Epochs = 260 | Loss = 0.520686686038971 | Params = OrderedDict([('weights', tensor([2.4591])), ('bias', tensor([-0.8258]))])
# Epochs = 270 | Loss = 0.5099056363105774 | Params = OrderedDict([('weights', tensor([2.4453])), ('bias', tensor([-0.8058]))])
# Epochs = 280 | Loss = 0.49912458658218384 | Params = OrderedDict([('weights', tensor([2.4314])), ('bias', tensor([-0.7858]))])
# Epochs = 290 | Loss = 0.4883435368537903 | Params = OrderedDict([('weights', tensor([2.4176])), ('bias', tensor([-0.7658]))])
# Epochs = 300 | Loss = 0.47966161370277405 | Params = OrderedDict([('weights', tensor([2.4037])), ('bias', tensor([-0.7458]))])
# Epochs = 310 | Loss = 0.47116318345069885 | Params = OrderedDict([('weights', tensor([2.3899])), ('bias', tensor([-0.7258]))])
# Epochs = 320 | Loss = 0.4626646637916565 | Params = OrderedDict([('weights', tensor([2.3760])), ('bias', tensor([-0.7058]))])
# Epochs = 330 | Loss = 0.45646438002586365 | Params = OrderedDict([('weights', tensor([2.3622])), ('bias', tensor([-0.6858]))])
# Epochs = 340 | Loss = 0.450303852558136 | Params = OrderedDict([('weights', tensor([2.3483])), ('bias', tensor([-0.6658]))])
# Epochs = 350 | Loss = 0.4441981315612793 | Params = OrderedDict([('weights', tensor([2.3342])), ('bias', tensor([-0.6463]))])
# Epochs = 360 | Loss = 0.4385852813720703 | Params = OrderedDict([('weights', tensor([2.3174])), ('bias', tensor([-0.6313]))])
# Epochs = 370 | Loss = 0.43297243118286133 | Params = OrderedDict([('weights', tensor([2.3007])), ('bias', tensor([-0.6163]))])
# Epochs = 380 | Loss = 0.42735958099365234 | Params = OrderedDict([('weights', tensor([2.2839])), ('bias', tensor([-0.6013]))])
# Epochs = 390 | Loss = 0.42174673080444336 | Params = OrderedDict([('weights', tensor([2.2672])), ('bias', tensor([-0.5863]))])
# Epochs = 400 | Loss = 0.4161338806152344 | Params = OrderedDict([('weights', tensor([2.2504])), ('bias', tensor([-0.5713]))])
# Epochs = 410 | Loss = 0.4107462465763092 | Params = OrderedDict([('weights', tensor([2.2326])), ('bias', tensor([-0.5583]))])
# Epochs = 420 | Loss = 0.40558379888534546 | Params = OrderedDict([('weights', tensor([2.2136])), ('bias', tensor([-0.5473]))])
# Epochs = 430 | Loss = 0.40047770738601685 | Params = OrderedDict([('weights', tensor([2.1943])), ('bias', tensor([-0.5368]))])
# Epochs = 440 | Loss = 0.3953152596950531 | Params = OrderedDict([('weights', tensor([2.1753])), ('bias', tensor([-0.5258]))])
# Epochs = 450 | Loss = 0.39020904898643494 | Params = OrderedDict([('weights', tensor([2.1561])), ('bias', tensor([-0.5153]))])
# Epochs = 460 | Loss = 0.3850466310977936 | Params = OrderedDict([('weights', tensor([2.1371])), ('bias', tensor([-0.5043]))])
# Epochs = 470 | Loss = 0.3799405097961426 | Params = OrderedDict([('weights', tensor([2.1178])), ('bias', tensor([-0.4938]))])
# Epochs = 480 | Loss = 0.3747781217098236 | Params = OrderedDict([('weights', tensor([2.0988])), ('bias', tensor([-0.4828]))])
# Epochs = 490 | Loss = 0.3696720004081726 | Params = OrderedDict([('weights', tensor([2.0795])), ('bias', tensor([-0.4723]))])

# %%
with torch.inference_mode():
    y_preds_ = model_0(X_test)
    
    loss = loss_fn(y_test, y_preds_)

# %%
y_preds_
# Out:
# tensor([[ 0.7745],
#         [-0.1741],
#         [-0.2566],
#         [ 0.5270],
#         [ 0.4858],
#         [ 0.8158],
#         [-0.3391],
#         [ 1.1870],
#         [ 1.3932],
#         [-0.2154]])

# %%
plot_prediction(prediction= y_preds_)

# %%
loss = loss_fn(y_preds_, y_test)
loss
# Out:
# tensor(0.3651)
